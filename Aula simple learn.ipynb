# %%
x= 2

# %%
type(x)
# Out:
# int

# %%
x= 'breno'

# %%
type(x)
# Out:
# str

# %%
print(x)
# Out:
# breno

# %%
x= [1,2,3]

# %%
print(x[0])
# Out:
# 1

# %%
x[2]=67

# %%
print(x)
# Out:
# [1, 2, 67]

# %%
print(x[2])
# Out:
# 67

# %%
x[1]=10

# %%
type(x)
# Out:
# list

# %%
print(x)
# Out:
# [1, 10, 67]

# %%
x=(2,3,4)

# %%
print(x)
# Out:
# (2, 3, 4)

# %%
type(x)
# Out:
# tuple

# %%
print(x[2])
# Out:
# 4

# %%
x=1
y=2
z=3

# %%
type(x)
# Out:
# int

# %%
(x,y,z)=1,2,3

# %%
x=y=z=1

# %%
print(x,y,z)
# Out:
# 1 1 1

# %%
(x,y,z)=1,2,3

# %%
print(x,y,z)
# Out:
# 1 2 3

# %%
x=s=e=2

# %%
a100=100
A100=200

# %%
print(a100,A100)
# Out:
# 100 200

# %%
x=[1,2,3]

# %%
type(x)
# Out:
# list

# %%
x[2]=55

# %%
print(x)
# Out:
# [1, 2, 55]

# %%
#Aritimetica

# %%
x=10
y=20

# %%
result=x+y

# %%
print(result)
# Out:
# 30

# %%
result=x//y

# %%
type(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 type(X)
#
# NameError: name 'X' is not defined

# %%
TYPE(X)

# %%
type(x)

# %%
print(result)

# %%
result=x/y

# %%
print(result)

# %% [markdown]
# STRING OPERATIONS

# %%
var = "bruno dias"

# %%
print(var)

# %%
print(var[2:3])

# %%
print(var[0:3])

# %%
print(var[:4])

# %%
var1='bom dia'
var2='meu amigo Charles'

# %%
var3=var1[:4]+var2[4:10]+var1[4:7]

# %%
print(var3)

# %% [markdown]
# CONDIÇÃO IF

# %%
a=9
if a<=10:
    if a%90==10:
        print("a é menor ou igual a 10")
    else:
        print("menor que 10")
else:
    print("maior que 10")
# Out:
# menor que 10
